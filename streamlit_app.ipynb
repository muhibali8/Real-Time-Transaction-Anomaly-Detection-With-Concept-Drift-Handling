# %% [markdown]
# *REAL-TIME TRANSACTION ANOMALY DETECTION WITH CONCEPT DRIFT HANDLING*

# %% [markdown]
# - Loading Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
from datetime import datetime, timedelta
from collections import deque, defaultdict

# %%
import streamlit as st

# %%
import plotly.express as px
from river import anomaly, compose, preprocessing, drift

# %% [markdown]
# *1 - Building a Realistic Transaction Stream*
#
# This is not ML code — it’s a data generator. Used to train and test fraud detection models.
#
# Without using real banking data.

# %% [markdown]
# *2- Generating Online Features*
#
#
# rolling_mean_5min
#
# rolling_count_5min
#
# rolling_max_5min
#
# user_rolling_mean_10min
#
# user_rolling_count_10min.
#
# diff_from_global_mean
#
# diff_from_user_mean

# %% [markdown]
# *3 - Online Anomaly Detection using River ( HalfSpaceTrees )*

# %%
np.random.seed(42)

# %%
def transaction_stream( n_events=1000, start_time=datetime.now(), fraud_rate=0.02 ):
    current_time=start_time
    for i in range(n_events):
        # simulate time gap between transactions
        current_time += timedelta(seconds=np.random.exponential(scale=20))  # smaller gap for denser data scale=8

        # user behavior
        user_id = np.random.randint(1,50)   # fewer users to get more per-user data  -- 1, 15

        # DRIFT AFTER 500 EVENTS

        if i < 500:
            normal_mean = 50
            normal_std = 5
        else:
            normal_mean = 600      # NEW NORMAL
            normal_std = 5

        # fraud or not
        is_fraud = np.random.rand() < fraud_rate

        # transaction amount
        if is_fraud:
            amount= np.random.normal(loc=800, scale=150)
        else:
            amount= np.random.normal(loc=normal_mean, scale=normal_std)

        yield {
            'timestamp': current_time,
            'user_id': user_id,
            'amount': max(1, round(amount, 2)),
            'is_fraud': int(is_fraud)
        }

events=[]
for event in transaction_stream(n_events=1000):
    events.append(event)


window_all=deque()
user_windows= defaultdict(deque)


window_duration_5min = timedelta(minutes=5)    # global window
window_duration_10min = timedelta(minutes=10)  # per-user window


model= compose.Pipeline(
            preprocessing.StandardScaler(),
            anomaly.HalfSpaceTrees(n_trees=15, height=3, window_size=200, seed=42)
        )

#Drift detector
adwin= drift.ADWIN(delta=0.2)


threshold=0.68  #for testing
scores=[]
alerts=[]
events_with_features= []
drift_points= []

# Optional: pause learning after drift
pause_learning = 0
pause_after_drift = 50

# Streamlit setup

st.set_page_config(page_title="Fraud Detection Monitor", layout="wide")
st.title('Real-Time Transaction Anomaly Detection')
st.sidebar.header('Metrics')
# Out:
# 2026-02-28 06:29:21.849 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:21.849 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:22.674
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\T470\miniconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-28 06:29:22.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:22.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:22.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:22.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:22.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator(_root_container=1, _parent=DeltaGenerator())

# %%
for event in transaction_stream(n_events=1000):
    # Remove old events outside window
    while window_all and (event['timestamp'] - window_all[0]['timestamp']) > window_duration_5min:
        window_all.popleft()

    #Remove old events from per-user window
    user_id= event['user_id']
    while user_windows[user_id] and (event['timestamp'] - user_windows[user_id][0]['timestamp']) > window_duration_10min:
        user_windows[user_id].popleft()

    # Compute global rolling features

    if window_all:
        rolling_mean= np.mean([e['amount'] for e in window_all])
        rolling_max= np.max([e['amount'] for e in window_all])
        rolling_std= np.std([e['amount'] for e in window_all])
        rolling_count= len(window_all)
    else:
        rolling_mean = event['amount']
        rolling_max = event['amount']
        rolling_std= 0
        rolling_count = 1

    # Compute per-user rolling features

    if user_windows[user_id]:
        user_rolling_mean= np.mean([e['amount'] for e in user_windows[user_id]])
        user_rolling_count= len(user_windows[user_id])

    else:
        user_rolling_mean = event['amount']
        user_rolling_count = 1


    diff_from_global_mean= event['amount'] - rolling_mean
    diff_from_user_mean= event['amount'] - user_rolling_mean


    event['rolling_mean_5min'] = rolling_mean
    event['rolling_max_5min'] = rolling_max
    event['rolling_std_5min'] = rolling_std
    event['rolling_count_5min'] = rolling_count
    event['user_rolling_mean_10min'] = user_rolling_mean
    event['user_rolling_count_10min'] = user_rolling_count
    event['diff_from_global_mean'] = diff_from_global_mean
    event['diff_from_user_mean'] = diff_from_user_mean

    # Add current event AFTER computing feature

    events_with_features.append(event)




    #building features
    features ={
        'rolling_mean_5min': rolling_mean,
        'rolling_max_5min': rolling_max,
        'rolling_std_5min': rolling_std,
        'rolling_count_5min': rolling_count,
        'user_rolling_mean_10min': user_rolling_mean,
        'user_rolling_count_10min': user_rolling_count,
        'diff_from_global_mean': diff_from_global_mean,
        'diff_from_user_mean': diff_from_user_mean,
        'amount': event['amount']

    }


    score= model.score_one(features)
    scores.append(score)

    alert= score>threshold
    alerts.append(alert)


    # Drift Detection
    drift_detected = adwin.update(diff_from_global_mean)

    if adwin.drift_detected:
        drift_points.append(event['timestamp'])

        model= compose.Pipeline(
            preprocessing.StandardScaler(),
            anomaly.HalfSpaceTrees(n_trees=15, height=3, window_size=200, seed=42)
        )
        pause_learning = pause_after_drift  # optionally skip learning to let scores spike


    # Model learning
    if pause_learning > 0:
        pause_learning -= 1
    else:
        model.learn_one(features)


    window_all.append(event)
    user_windows[user_id].append(event)


# DataFrame for Streamlit

df_live = pd.DataFrame(events_with_features)
df_live['scores']= scores
df_live['alerts']= alerts


# Streamlit visualizations

#Metrics

col1, col2, col3, col4 = st.columns(4)

col1.metric("Total Transactions", len(df_live))
col2.metric("Total Alerts", sum(alerts))
col3.metric("Max Anomaly Score", np.round(max(scores),2))
col4.metric("Drift Detections:", len(drift_points))


st.sidebar.metric("Total Transactions", len(df_live))
st.sidebar.metric("Total Alerts:", sum(alerts))
st.sidebar.metric("Max Anomaly Score:", np.round(max(scores),2))
st.sidebar.metric("Drift Detections:", len(drift_points))


# Recent Transactions Table

st.subheader('Recent Transactions')
st.dataframe(df_live.tail(20))


# Color-Coded Alerts

latest = df_live.iloc[-1]

if latest['alerts'] == 1:
    st.write("Latest score:", latest["scores"])
    st.write("Alert value:", latest["alerts"])
    st.error(f" ALERT: User {latest['user_id']} | Amount: {latest['amount']} | Score: {np.round(latest['scores'],2)}")
else:
    st.write("Latest score:", latest["scores"])
    st.write("Alert value:", latest["alerts"])
    st.success("Latest transaction: Normal")


# Anomaly Scores over time

st.subheader('Anomaly Scores')
fig_scores= px.line(df_live , x='timestamp', y='scores', color='user_id', title='Anomaly Scores By Users Over Time')
st.plotly_chart(fig_scores, use_container_width=True)


# Alerts Panel

st.subheader("Alerts Panel")


alerts_df = df_live[df_live["alerts"] == True]

if len(alerts_df) == 0:
    st.success("No anomalies detected.")
else:
    st.error(f"{len(alerts_df)} anomalies detected!")

    # Show only important columns
    display_cols = [
        "user_id",
        "amount",
        "scores"
    ]

    # Sort by highest anomaly score
    alerts_df = alerts_df.sort_values(by="scores", ascending=False)

    st.dataframe(alerts_df[display_cols], use_container_width=True)


# Rolling Stats

st.subheader('Rolling Statistics')
fig_rolling= px.line(df_live, x='timestamp', y=['rolling_mean_5min', 'user_rolling_mean_10min'], title='Global & Per-User Rolling Means')
st.plotly_chart(fig_rolling, use_container_width=True)


#Per-User Risk Summary Table

summary = df_live.groupby("user_id").agg(
    total_transactions=("amount", "count"),
    total_alerts=("alerts", "sum"),
    avg_amount=("amount", "mean"),
    max_score=("scores", "max")
).reset_index()

st.subheader("Per-User Risk Summary")
st.dataframe(summary)


# Concept Drift Points

st.subheader('Concept Drift Detected')
for drift_time in drift_points:
    st.markdown(f'Concept Drift Detected at {drift_time}')
# Out:
# 2026-02-28 06:29:23.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.578 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-02-28 06:29:23.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.609 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-02-28 06:29:23.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.681 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-02-28 06:29:23.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-28 06:29:23.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# - To open streamlit dashboard

# %% [markdown]
# Install Python 3.10
#
# During installation, **check “Add Python 3.10 to PATH”**.
#
#
# Open **terminal** and run:
#
#
# py -3.10 --version
#
# Create a virtual environment**
#
# py -3.10 -m venv fraud_env
#
# Activate the environment:
#
# .fraud_env\Scripts\activate.bat
#
#
# python -m pip install --upgrade pip
#
# pip install streamlit pandas numpy plotly river

# %%
# !pip install streamlit
# !streamlit run streamlit_app.py
# Out:
# Requirement already satisfied: streamlit in c:\users\t470\miniconda3\lib\site-packages (1.54.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=5.5 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (2.0.1)
# Requirement already satisfied: packaging>=20 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (6.33.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\t470\miniconda3\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\t470\miniconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\t470\miniconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\t470\miniconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.10.2)
# Requirement already satisfied: colorama in c:\users\t470\miniconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\t470\miniconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\t470\miniconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\t470\miniconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\t470\miniconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\t470\miniconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\t470\miniconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\t470\miniconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\t470\miniconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\t470\miniconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\t470\miniconda3\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\t470\miniconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\t470\miniconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\t470\miniconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\t470\miniconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\t470\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
